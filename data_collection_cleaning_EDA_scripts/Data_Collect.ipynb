# %%
import string

# %%
import pandas as pd
import re
from bs4 import BeautifulSoup

# %% [markdown]
# # The Economist

# %%
import requests
 
URL = "https://www.economist.com/economics-a-to-z/a"
r = requests.get(URL)

# %%
soup = BeautifulSoup(r.content, 'html5lib')

# %%
li = soup.find_all('div', {"class": " ec-glossary-type node node-type-economics_term node-published node-teaser clearfix"})
dtt = [(i.find('h2').text, i.find('p').text) for i in li]

# %%
pd.DataFrame(dtt, columns=['terms', 'links'])
# Out:
#                        terms                                              links
# 0         Absolute advantage  This is the simplest yardstick of economic per...
# 1      Adaptive expectations  A theory of how people form their views about ...
# 2          Adverse selection  When you do business with people you would be ...
# 3                Advertising  Many firms advertise their goods or services, ...
# 4               Agency costs  These can arise when somebody (the principal) ...
# 5        Agricultural policy  Countries often provide support for their farm...
# 6                Agriculture  Farming around the world continues to become m...
# 7                        Aid                             See international aid.
# 8                   Altruism  It is often alleged that altruism is inconsist...
# 9               Amortisation  The running down or payment of a loan by insta...
# 10            Animal spirits  The colourful name that keynes gave to one of ...
# 11                 Antitrust  government policy for dealing with monopoly. A...
# 12              Appreciation  A rise in the value of an asset and the opposi...
# 13                 Arbitrage  Buying an asset in one market and simultaneous...
# 14  Arbitrage pricing theory  This is one of two influential economic theori...
# 15              Asian crisis  During 1997-98, many of the East Asian tiger e...
# 16                    Assets  Things that have earning power or some other v...
# 17    Asymmetric information  When somebody knows more than somebody else. S...
# 18          Asymmetric shock  When something unexpected happens that affects...
# 19                  Auctions  Going, going, gone. Holding an auction can be ...
# 20        Austrian economics  A brand of neo-classical economics established...
# 21                   Autarky  The idea that a country should be self-suffici...
# 22                   Average  A number that is calculated to summarise a gro...

# %%
all_econ = pd.DataFrame({})
base_url = "https://www.economist.com/economics-a-to-z/"
for ch in 'abcdefghijklmnopqrstuvwxyz':
  r = requests.get(base_url+ch)
  soup = BeautifulSoup(r.content, 'html5lib') 
  li = soup.find_all('div', {"class": " ec-glossary-type node node-type-economics_term node-published node-teaser clearfix"})
  dtt = [(i.find('h2').text, i.find('p').text) for i in li]
  all_econ = all_econ.append(pd.DataFrame(dtt, columns=['terms', 'definitions']))

# %%
 all_econ['source'] = 'economist'

# %%
# !pip install textstat
# Out:
# Collecting textstat
#   Downloading textstat-0.7.2-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 10.3 MB/s
# Collecting pyphen
#   Downloading pyphen-0.11.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 23.6 MB/s
# Installing collected packages: pyphen, textstat
# Successfully installed pyphen-0.11.0 textstat-0.7.2

# %%
import textstat

# %%
def extract_scores(test_data):
  try:
    scores = [textstat.flesch_reading_ease(test_data),textstat.flesch_kincaid_grade(test_data),textstat.smog_index(test_data),textstat.coleman_liau_index(test_data), textstat.automated_readability_index(test_data),textstat.dale_chall_readability_score(test_data), textstat.difficult_words(test_data), textstat.linsear_write_formula(test_data), textstat.gunning_fog(test_data), textstat.text_standard(test_data), textstat.fernandez_huerta(test_data), textstat.szigriszt_pazos(test_data), textstat.gutierrez_polini(test_data), textstat.crawford(test_data), textstat.gulpease_index(test_data), textstat.osman(test_data)]
  except:
    scores = [0.0]*9 + ['NOT USE'] + [0.0]*6
  return scores

# %%
scores = all_econ['definitions'].apply(lambda x: extract_scores(str(x)))
scores_df = pd.DataFrame(list(scores))
scores_df.columns = ['flesch_reading_ease','flesch_kincaid_grade','smog_index','coleman_liau_index','automated_readability_index','dale_chall_readability_score','difficult_words','linsear_write_formula','gunning_fog','text_standard','fernandez_huerta','szigriszt_pazos','gutierrez_polini','crawford','gulpease_index','osman']
scores_df
# Out:
#      flesch_reading_ease  flesch_kincaid_grade  ...  gulpease_index  osman
# 0                  53.61                  10.2  ...       52.181818  46.08
# 1                  64.20                   8.2  ...       58.677419  59.47
# 2                  54.15                  12.0  ...       51.834646  50.77
# 3                  21.74                  16.2  ...       42.645833  25.55
# 4                  46.44                  15.0  ...       47.787879  40.77
# ..                   ...                   ...  ...             ...    ...
# 651                38.66                  13.8  ...       48.722222  41.42
# 652                63.70                   8.4  ...       63.375000  72.71
# 653                55.68                  11.4  ...       50.623037  49.58
# 654                59.33                  10.0  ...       53.426230  53.43
# 655                53.21                  10.3  ...       54.000000  52.21
#
# [656 rows x 16 columns]

# %%
all_econ_scores_df = pd.concat([all_econ.reset_index(),scores_df.reset_index()], axis = 1).drop('index', axis = 1)
all_econ_scores_df
# Out:
#                      terms  ...  osman
# 0       Absolute advantage  ...  46.08
# 1    Adaptive expectations  ...  59.47
# 2        Adverse selection  ...  50.77
# 3              Advertising  ...  25.55
# 4             Agency costs  ...  40.77
# ..                     ...  ...    ...
# 651           X-efficiency  ...  41.42
# 652                  Yield  ...  72.71
# 653            Yield curve  ...  49.58
# 654              Yield gap  ...  53.43
# 655          Zero-sum game  ...  52.21
#
# [656 rows x 19 columns]

# %%
all_econ_scores_df.to_csv('all_econ_scores_df.csv', index = False)

# %% [markdown]
# # Federal Reserve Bank St. Louis

# %%
#https://www.stlouisfed.org/education/glossary#sr_education%20level=9--12
#https://www.stlouisfed.org/education/glossary#sr_education%20level=College
#https://www.stlouisfed.org/education/glossary#sr_education%20level=Non--educators
#https://www.stlouisfed.org/education/glossary#sr_education%20level=Pre--K--5
#https://www.stlouisfed.org/education/glossary#sr_education%20level=6--8

# %%
def file_to_df(fl):
  lines = open(fl,'r').read().splitlines()
  terms, definitions = [],[]
  for i in range(len(lines)):
    if i%2==0:
      terms.append(lines[i])
    else:
      definitions.append(lines[i])
  df = pd.DataFrame({'terms':terms, 'definitions':definitions})
  df['source'] = fl.replace('.txt', '')

  scores = df['definitions'].apply(lambda x: extract_scores(str(x)))
  scores_df = pd.DataFrame(list(scores))
  scores_df.columns = ['flesch_reading_ease','flesch_kincaid_grade','smog_index','coleman_liau_index','automated_readability_index','dale_chall_readability_score','difficult_words','linsear_write_formula','gunning_fog','text_standard','fernandez_huerta','szigriszt_pazos','gutierrez_polini','crawford','gulpease_index','osman']

  df_scores_df = pd.concat([df.reset_index(),scores_df.reset_index()], axis = 1).drop('index', axis = 1)
  return df_scores_df

# %%
six_eight = file_to_df('6_8_louis.txt')
nine_twelve = file_to_df('9_12_louis.txt')
college = file_to_df('college_louis.txt')
non_edu = file_to_df('non_educators_louis.txt')
pre_lou = file_to_df('pre_louis.txt')

# %%
all_louis = six_eight.append(nine_twelve).append(college).append(non_edu).append(pre_lou)

# %%
all_louis
# Out:
#                               terms  ...  osman
# 0                Absolute advantage  ...  60.85
# 1    Adjustable-rate mortgage (ARM)  ...  57.42
# 2             Adjusted gross income  ...  21.61
# 3                        Allocation  ...  62.69
# 4    Alt-A (Alternative A) mortgage  ...  13.07
# ..                              ...  ...    ...
# 173            Utility/Satisfaction  ...  33.14
# 174              Wages (elementary)  ...  80.83
# 175                           Wants  ...  60.06
# 176                        Warranty  ...  63.05
# 177                           Waste  ...  35.46
#
# [2929 rows x 19 columns]

# %%
all_louis.to_csv('all_louis_gradewise.csv', index = False)

# %% [markdown]
# # Palgrave

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading PyPDF2-1.26.0.tar.gz (77 kB)
#      |████████████████████████████████| 77 kB 5.6 MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... canceled
# ERROR: Operation cancelled by user

# %%
import PyPDF2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-86-69e9e6162b4c> in <module>()
# ----> 1 import PyPDF2
#
# ModuleNotFoundError: No module named 'PyPDF2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def extract_text(pdf_name):
  content = ''

  # creating a pdf file object 
  pdfFileObj = open(pdf_name, 'rb')
  
  # creating a pdf reader object 
  pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
  for pg_no in range(pdfReader.getNumPages()):
    #print(pg_no)
    # creating a page object 
    pageObj = pdfReader.getPage(pg_no) 
    content = content + str(pageObj.extractText())
  pdfFileObj.close()
  return content

# %%
palgrave = extract_text('The Palgrave Macmillan Dictionary of Finance, Investment and Banking by Erik Banks (auth.) (z-lib.org)-pages-35-587.pdf')

# %%
palgrave

# %%
# Palgrave pdf to html : using https://www.pdftohtml.net/ (not good) and https://pdf.online/convert-pdf-to-html (better)

# %%
soup = BeautifulSoup(open("palgrave_better.html", "r"), 'html.parser')

# %%
import re

# %%
#soup.find_all('span', {"class": "ft2"})
soup.find_all('p', {"class": re.compile("\ft3$")})

# %%
soup.find_all(re.compile("\ft3$"))

# %%
soup.findAll(p=re.compile("\ft3$"))

# %%
[i for i in soup.find_all('p', {'class' : re.compile('ft3$')})]

# %%
li = soup.find_all('p', {'class' : re.compile('ft3$')})

# %%
li[0].text

# %%
li[0].text.split('</span>')

# %%
term_defn = []
for cnt,i in enumerate(soup.find_all('p', {'class' : re.compile('ft3$')})):
  term = ' '.join([j.text.strip() for j in i.find_all('span', {'class':"ft2"})])
  all_text = i.text
  definition = all_text.replace(term, '').strip()
  if term.strip() != '':
    term_defn.append([term, definition])
  else:
    term_defn[-1][1] = term_defn[-1][1] + definition

# %%
palgrave_df = pd.DataFrame(term_defn, columns = ['terms', 'definitions'])
palgrave_df['source'] = 'palgrave'

# %%
palgrave_df.sample(60)

# %%
scores = palgrave_df['definitions'].apply(lambda x: extract_scores(str(x)))
scores_df = pd.DataFrame(list(scores))
scores_df.columns = ['flesch_reading_ease','flesch_kincaid_grade','smog_index','coleman_liau_index','automated_readability_index','dale_chall_readability_score','difficult_words','linsear_write_formula','gunning_fog','text_standard','fernandez_huerta','szigriszt_pazos','gutierrez_polini','crawford','gulpease_index','osman']

# %%
palgrave_scores_df = pd.concat([palgrave_df.reset_index(),scores_df.reset_index()], axis = 1).drop('index', axis = 1)
palgrave_scores_df

# %%
palgrave_scores_df.to_csv('palgrave_scores_df.csv', index = False)

# %% [markdown]
# # Heather

# %%
soup = BeautifulSoup(open("heather.html", "r"), 'html.parser')

# %%
li = soup.find_all('p', {'class' : [re.compile('^p1 '), re.compile('^p0 ')]})

# %%
'2'.isnumeric()
# Out:
# True

# %%
#terms 2,10,11 18, 6, 13, 22, 20
terms = [i.text.strip() for i in soup.find_all('span', {'class':["ft2", "ft6","ft10","ft11", "ft13","ft18", "ft20", "ft22"]}) if i.text.strip()!='' and i.text.strip().replace('.','').replace('–','').replace('(','').replace(')','').isnumeric()==False]
terms_to_remove = ['noun ', ',', 'f.', 'name', 'A']
terms_use = [i for i in terms if i not in terms_to_remove]

# %%
[i.text for i in soup.find_all('p')]
# Out:
# ['A, AA, AAA noun letters indicating that a share o certain rating for reliability. The AAA rating (called t given by Standard & Poor’s or by Moody’s Investors Se very high level of reliability for a corporate or municipal',
#  'ability to pay theory noun the theory of taxa taxation should be related to the taxpayer’s ability to higher incomes pay tax at a higher rate than those on low basis of progressive taxation. Many taxes, such as VAT, are not linked to the purchaser’s ability to pay and ar taxation.',
#  'abscissa noun the horizontal value on a graph. Th y-value or ordinate. Also called x-value (NOTE: The pl',
#  'abscissas.)',
#  'absolute advantage, absolute cost advanta',
#  'in which a country, or sometimes a person or company producing something than its competitors (i.e. its out higher). This gives an advantage to established firms low in comparison to new entrants.',
#  'absolute value noun the size or value of a number The absolute value of –62.34 is 62.34.',
#  'absorption costing, absorption pricing no price of a product to include both the direct costs of pro the overhead costs which are absorbed as well. Absor three stages: allocation of actual overhead costs directly which they relate; apportionment, by which common divided between various cost centres in proportion to th each cost centre; absorption, by which the total costs are of production.',
#  'ACAS abbreviation Advisory, Conciliation and Arbitr',
#  'accelerated depreciation noun a system o reduces the value of assets at a high rate in the earl companies to invest in new equipment, because of the applied in the UK until 1984: companies could depreci 100% in the first year. The system still applies in the US',
#  'demand which itself leads to an increase in output which i further increase in investment. Also called multiplier-ac',
#  'accelerator principle noun the principle that a c demand will have an even greater percentage change o capital goods, so that firms produce more of a commodi rising and less when demand is falling. This has the eff booms and depressions in the economy. Also call',
#  'principle',
#  'acceptance noun the act of signing a bill of exchang agree to pay it',
#  'acceptance bank noun US same as accepting ho',
#  'accepting house, acceptance house noun merchant bank, which accepts bills of exchange (i.e. pro and is paid a commission for this',
#  'accommodating monetary policy,',
#  'monetary policy noun a policy which allows money su the demand for money increases',
#  'account noun STOCK EXCHANGE the period during whic for credit, and at the end of which the shares bought must London Stock Exchange, the account period is three busi day of trade. (NOTE: On the London Stock Exchange, th',
#  'accounts during the year, each running usually for ten working',
#  'account day noun the day on which shares which hav be paid for. On the London Stock Exchange the acco business days from the day of trade. Also called settleme',
#  'accounting entity noun same as accounting unit',
#  'accounting period noun the period usually cover accounts. The balance sheet shows the state of the comp end of the accounting period, while the profit-and-loss changes which have taken place since the end of the previo',
#  'accounting unit noun any unit which takes part in fi which are recorded in a set of accounts. It can be a departm Plc or some other unit.',
#  'goodwill.',
#  'ACT abbreviation Advance Corporation Tax',
#  'activity indicator noun an indicator such as i capacity utilisation, and volume of retail sales, which s the business cycle the economy is',
#  'activity rate noun the percentage of the population are actually in active employment. Also called econo',
#  'labour force participation rate',
#  'actual growth noun the final actual result Harrod-Domar model',
#  'actuary noun a person employed by an insuranc organisation to calculate the risk involved in an insuran premiums payable by persons taking out insurance',
#  'adaptive expectations noun the theory tha because of what people expect will happen: so worke because they believe inflation will rise, and this increase an increase in inflation; similarly economists will exag forecasts to take into account errors they made in pre adaptive expectations always exaggerate upward or',
#  'expectations lag',
#  'ADB abbreviation 1. African Development Bank 2 Bank',
#  'adjustable peg regime, adjustable peg syst',
#  'which a currency is pegged to another, but with the poss exchange rate from time to time',
#  'administered price noun US same as recomme',
#  'administration noun the appointment by a court o the affairs of a company which is in difficulties',
#  'ADR abbreviation American depositary receipt',
#  'ad valorem tax noun a tax (such as VAT) which is to the value of the goods or services taxed. Compare sp',
#  'advance noun an amount of money paid as a loan or to be made later  adjective paid as a loan or as a pa',
#  'and buyers are not capable of judging if the quality or pr applies in many commercial spheres, such as the stock mar well as in general trading. Three factors come into play: (i) of similar products on the market; (ii) the fact that buyers possess the same information about the product (usually th than the buyer); (iii) sellers are more likely to want to ge products than good quality products. Also called lemon p',
#  'adverse supply shock noun shock caused to sudden stoppage in the supply of raw materials or other i would be the reduction in supply of oil caused by a war.',
#  'advertising noun the business of announcing that som of trying to persuade customers to buy a product or service will stimulate sales, but the cost will be borne eventually b',
#  'Advisory, Conciliation and Arbitration S',
#  'government service founded in 1974 which offers facilities representatives of their workforce to meet and try to so matters such as employees’ rights or union recognition. Ab',
#  'AE abbreviation aggregate expenditure',
#  'African Development Bank noun a bank set up b to provide long-term loans to help agricultural developmen of the infrastructure. The bank now has non-African mem',
#  'ADB',
#  'age-earnings profile noun a graph showing the ear different ages and in different industries',
#  'agency shop noun US a contract arrangement maki workers who refuse to join a union to pay the union a fee',
#  'agent noun 1. a person who represents a company or a area 2. US the chief local official of a trade union',
#  'agglomeration economies plural noun econo achieve by being located in large urban areas',
#  'aggregate concentration noun the proportion o is in the hands of a few large companies',
#  'and foreign purchasers (i.e. exports minus imports) domestic product. Abbreviation AE',
#  'aggregate output noun a method of calculating t adding the total value added at each stage of product industry, service industry and agriculture, together with abroad',
#  'aggregate supply noun the total production o available to meet the aggregate demand during a given p',
#  'aggregate supply curve noun a curve showing at each price level; in the long term, supply pushes up pr',
#  'AGM abbreviation Annual General Meeting',
#  'agricultural sector noun the sector of an e agriculture, forestry and fishing',
#  'aid noun help given to a business or region by a govern AIM abbreviation Alternative Investment Market',
#  'alienation noun worker dissatisfaction, the lack of when a worker cannot see any positive result of his or he',
#  'allocative efficiency noun the action of satisfyin customer demands for goods and services by pricing the near to the production cost while still allowing a margin market is allocatively efficient it produces the right am right prices for the right customers.',
#  'Alternative Investment Market noun a L regulated by the London Stock Exchange, dealing companies which are not listed on the main London AIM is a way in which smaller companies can sell sh public without going to the expense of obtaining Abbreviation AIM',
#  'alternative technology noun the use of metho which are different and less polluting than the usual w power, tidal power or solar power, as opposed to traditio',
#  'American Depositary Receipt noun a doc American bank to US citizens, making them unregis companies in foreign countries. The document allo',
#  'between sections of a population which is being sampled',
#  'Andean Pact noun a trading agreement signed in 19 of Bolivia, Columbia. Ecuador, Peru and Venezuela. T member countries are reduced and a system of prefere members of the group introduced.',
#  'annual allowance noun an allowance against tax each year, such as annual depreciation of assets',
#  'Annual General Meeting noun an annual meeting of a company, when the company’s financial situation i discussed with the directors, when the accounts for the pas and when dividends are declared and audited. Abbreviatio',
#  'US term is annual meeting or annual stockholders’',
#  'Annual Percentage Rate noun a rate of inter hire-purchase agreement) shown on an annual compound b and charges. As hire purchase agreements quote a flat rate the whole amount borrowed or a monthly repayment fig Credit Act, 1974, forces lenders to show the APR concerning hire purchase agreements, so as to give an ac real rate of interest as opposed to the nominal rate. The AP fees charged (such as the valuation of a house for mortgag according to the sum borrowed – a credit card company APR if the borrower’s credit limit is low. Abbreviation AP',
#  'annual report and accounts noun the report fr the company’s financial situation at the end of a year, balance sheet, profit and loss account, statement of source funds, and the auditor’s report, all prepared for the s company each year',
#  'annuity noun an amount of money paid each year t usually in return for a lump-sum payment. The value of t on how long the person lives, as it usually cannot be pa person. Annuities are fixed payments, and lose their va whereas a pension can be index-linked. When people retir by law to purchase a compulsory purchase annuity with the in their pension fund. This gives them a taxable income',
#  'goods imported includes a subsidy from the governm origin. Also called countervailing duty',
#  'anti-globalisation movement noun an umb several hundred groups of people with different aims: p resources, anti-exploitation of native peoples, etc. movement also contains extreme left-wing groups who u cover for extremist and violent protests. Abbreviation A',
#  'anti-trust laws, legislation plural noun laws prevent the formation of monopolies or price fixin competition',
#  'APACS noun an organisation set up in 1985 by Briti societies to manage the networks by which money is tran accounts on behalf of customers (CHAPS and',
#  'Association for Payment Clearing Services',
#  'APC abbreviation average propensity to consume APM abbreviation average propensity to import APP abbreviation average physical product',
#  'applied economics noun the application of eco real world, formulated by economists as advice to plann',
#  'appreciation noun the increase in value of an asset',
#  'appreciation',
#  'appropriate technology noun technology whic environment, usually involving skills or materials whic locally. In many parts of world, devices to help the loca the land can be made out of simple pipes or pieces tractors may not only be unsuitable for the terrain invol which costs more than the crops produced.',
#  'appropriation account noun a part of a profit a shows how each part of the profit has been dealt with (s been given to the shareholders as dividends, how much reserves or what proportion of the profits comes from su',
#  'APR abbreviation Annual Percentage Rate',
#  'apriori adverb on the basis of ideas or assumptions, n',
#  'Arbitrageurs buy shares in companies which are potenti either to force up the price of the shares before the takeove position while waiting for the takeover bid to take place. T in the company which is expected to make the takeover b consequences of a takeover bid is usually that the price of rises while that of the bidding company falls. Arbitrageur shares in the target company at a profit, either to one of the takeover bid, or back to the company itself.',
#  'arbitration noun the settlement of a dispute by the two using an arbitrator (an outside person chosen by both sides',
#  'arc elasticity noun a reasonably accurate method proportional change in one variable compared with a prop another',
#  'arithmetic average noun a number calculated b several figures and dividing by the number of figures adde',
#  'arithmetic progression noun a sequence of numb difference between them, such as 2, 5, 8, 11. Com',
#  'progression',
#  'Arrow, Kenneth (1921–) American economist, w Prize for Economics in 1972, particularly interested i decision-making. He showed that a series of acceptable cho in a group will inevitably lead to the choice of one individu',
#  'Arrow’s impossibility theorem noun the theor two or more it may happen that it becomes impossible t majority voting which accurately reflects the preferences o group. Either the result goes against the majority preferen for a single individual to make the final decision.',
#  'articles of partnership plural noun same',
#  'agreement',
#  'ASEAN abbreviation Association of Southeast Asian N',
#  'Ashares plural noun ordinary shares with limited votin to vote at all. A company may be set up with two classes which are available to the general investor, and B shar bought by certain individuals, such as the founder and his division of shares is becoming less usual nowadays.',
#  'assets revaluation reserve noun an amount o not paid as dividend, but kept back by a company t company’s assets are revalued',
#  'asset stripping noun the buying of a company at asset value, and then selling its assets',
#  'assisted area noun area of a country which government to under European Union legislation. They levels higher than the norm in the European Union an increasing employment are given to companies, sole tr for capital expenditure (not general jobs which otherw Currently the areas are being reduced because Britain’s u lower than the European Union average.',
#  'Association of Southeast Asian Nations',
#  'formed originally in 1967 to promote economic educational development and general stability in Southe members are: Brunei, Indonesia, Laos, Malaysia, M Singapore, Thailand and Vietnam. Abbreviation ASEA',
#  'assurance noun an agreement that in return for company will pay compensation for loss of life, or will insured person lives to a certain age. Also called li',
#  'insurance',
#  'asymmetric information noun a situation countries where all the consumers, suppliers and produ same information on which to base their decisions',
#  'ATM abbreviation automated telling machine',
#  'atomistic competition noun same as perfect c',
#  'auction noun a method of selling goods in which peo item is sold to the person who makes the highest offer Dutch auction where the seller names a high price and until someone makes a bid.  verb to sell goods at auctio',
#  'audit noun the examination of the books and accounts to examine the books and accounts of a company',
#  'auditor noun a person, firm or partnership whic accounts. Audits can be external, that is independent f',
#  'auditors’ report noun a report written by a compa they have examined the accounts of the company (if the report certifies that, in the opinion of the auditors, the acco fair view of the company’s financial position)',
#  'Austrian school noun a school of economic study Vienna during the later part of the 19th century und emphasised the concept of utility – i.e. the pleasure derive from the product, as opposed to the value concepts of pro Later Austrian economists developed the theory of interest',
#  'authorised capital noun the maximum capital whic company’s articles of association',
#  'autocorrelation noun same as serial correlation',
#  'automated teller machine noun a machine wh when a special card is inserted and special instructions g',
#  'ATM',
#  'automatic stabilisers plural noun changes in gove in government tax revenue which are not caused by polic events such as the rise in unemployment during a recessi government spending on benefits, and at the same time revenue. Also called built-in stabilisers',
#  'automation noun the use of machines to do wor supervision by people',
#  'autonomous consumption, autonomous e',
#  'national consumption expenditure which does not vary wi but which represents expenditure which is necessary to standard of living even when personal incomes are zero. It GDP, but can have an effect on the economy.',
#  'autonomous investment noun investment whic increases or decreases in national income or in ouput, but w factors such as changes in government policy or the inventions',
#  'AVC abbreviation average variable cost',
#  'fixed costs by the number of units produced. The cost number of units produced.',
#  'average income per capita noun same as per average physical product, average produ',
#  'output per unit of variable input, such as the averag Abbreviation APP',
#  'average price level noun the average price of a p country at a particular time. Also called price level',
#  'average product noun same as average physic',
#  'average propensity to consume noun th disposable income (per individual, per household or nat Abbreviation APC',
#  'average propensity to import noun the disposable income (per individual, per household or na on imports. Abbreviation APM',
#  'average propensity to save noun the proporti income (per individual, per household or national) whi used for savings as opposed to expenditure. Abbreviatio',
#  'average rate of tax noun a figure calculated income tax paid by a person by his or her total income.',
#  'rate of tax',
#  'average revenue noun the revenue from one calculated as the total revenue divided by the number same as the average price.',
#  'average revenue product noun the revenue d of variable input',
#  'average total cost noun the total cost per unit, c the total costs by the number of units produced. It is the cost and average variable cost.',
#  'average variable cost noun the variable cost p dividing the variable costs by the number of units produ falls with the number of units produced but then ris produced – it forms a U-shaped curve. Abbreviation AV',
#  'back door noun financing by the Bank of England supply by selling Treasury bills. This is opposed to fron houses which run short of cash ask the Bank to make t which it does at a high interest rate.',
#  'back-to-back loan noun a loan from one compa currency arranged against a loan from the second co another currency. Back-to-back loans are used by intern get round exchange controls. Also called parallel loan',
#  'backwardation noun the difference between the sp as when the spot price of a commodity or currency is h price (NOTE: The opposite is forwardation.)',
#  'backward-bending supply curve noun a cu when the price of goods or services rises, so the quantity',
#  'Also called backward-sloping supply curve, labo',
#  'backward integration noun a situation in which another which is at an earlier stage in the production o when a supermarket purchases a milk company. A',
#  'integration (NOTE: The opposite is forward integrati',
#  'backward-sloping labour supply curv',
#  'backward-bending supply curve',
#  'BACS abbreviation Bankers Automated Clearing Ser',
#  'bad debt noun a debt which will never be paid (usua has gone out of business) and which has to be written of',
#  'bad debt provision noun money put aside i potential bad debts, which are likely to have to be writ provision is deducted from trade debtors for balance sh change in the provision from one year to the next togeth written off is the charge for bad debts in the profit and lo',
#  'bad money drives out good Gresham’s law, of money with the same denomination exist in the same the higher metal value will be driven out of circulation and use the lower-rated form to spend (as when paper m same denomination exist in the same market)',
#  'equivalent change in tax revenue',
#  'balanced growth noun a situation in which all sec grow at the same constant rate. Compare steady-state g',
#  'balance of payments noun a statement of the int position of a country, showing transactions which have certain period, usually one financial quarter. It includes i visible trade; all trade and movements of money between country and other countries worldwide, including expor purchases which when added must produce a balance. A b deficit occurs when a country imports more than it expo more in foreign currency than it earns; this is also called balance-of-payments surplus occurs when a country s countries than it buys from them. Abbreviation BOP',
#  'balance of payments deficit noun same as trad',
#  'balance of trade noun the international trading posi merchandise, excluding invisible trade. If exports are g there is a balance of trade surplus (or favourable balance o',
#  'trade balance',
#  'balance sheet noun a statement of the financial posit a particular time, such as the end of the financial year or t showing the company’s assets and liabilities. The balan state of a company’s finances at a certain date. The prof shows the movements which have taken place since the las since the end of the previous accounting period. A balance with the basic equation that assets (i.e. what the compa money owed to the company) must equal liabilities (i.e. owes to its creditors) plus capital (i.e. what it owes to i balance sheet can be drawn up either in the horizontal fo and capital on the left-hand side of the page (in the USA, it the vertical form, with assets at the top of the page, followe capital at the bottom. Most are usually drawn up in the opposed to the more old-fashioned horizontal style.',
#  'balances with the Bank of England pl deposited by commercial banks and building societies England, either to settle accounts with other banks or as a r',
#  'bank account noun an arrangement that a custo where the customer can deposit and withdraw money (',
#  'banking account.)',
#  'bank advance noun same as bank loan bank bill noun US same as banknote',
#  'bank credit noun credit in the form of loans or o banks to their customers',
#  'bank deposits plural noun all money placed in corporate customers',
#  'Bankers’ Automated Clearing Services',
#  'up to organise the payment of direct debits, standing o and other payments generated by computers. It operat clearing banks and several building societies, and fo Abbreviation BACS. Compare Clearing House Aut',
#  'System',
#  'banker’s draft noun an order by one bank telling in another country) to pay money to someone',
#  'Bank for International Settlements noun a clearing bank for the central banks of various countries settle their currency transactions and also acts on behalf in Basel, Switzerland. Abbreviation BIS',
#  'banking account noun US same as bank accou',
#  'banking system noun the system of banks in commercial banks, merchant banks and the central bank',
#  'bank loan noun a loan made by a bank to a custom security of a property or asset. Also called bank advan',
#  'banknote noun a promissory note issued by a bank bearer on demand and is acceptable as money (NOTE: The',
#  'Bank of England noun the central British bank which, together with the Treasury, regulates the nation’ of England issues banknotes which carry the signatures o lender of last resort to commercial banks and supervise in the UK. Its Monetary Policy Committee is independe',
#  'also cannot borrow money. In the USA, there are two ty involuntary, where the creditors ask for a person or corp bankrupt; and voluntary, where a person or corporation bankrupt (in the UK, this is called voluntary liquidation).',
#  'bankruptcies.)',
#  'bank statement noun a written statement from a balance of an account',
#  'bar chart noun a chart where values or quantities a columns of the same width but different heights. Also c',
#  'histogram',
#  'bargaining noun the act of discussing a price, usually workers',
#  'bargaining theory of wages noun the theory bargaining, that an agreement should be reached which is management and workers, and which is not detrimen profitability of the company',
#  'bar graph noun same as bar chart',
#  'barometric price leader noun a firm which fixes or service in a market, which other firms then follow',
#  'barrier noun something which restricts commercial ac restricting movement of capital or labour',
#  'barrier to entry noun something which makes it di enter a market and compete with firms already in that mark are mainly government legislation, the cost of starting up current ownership of resources and patents, and the stre already in the market. Barriers to entry may be created, a already in a market have patents that prevent their goods when the cost of the advertising needed to gain a market s when an existing product commands very strong brand loy',
#  'barrier to exit noun something which make it difficul a market, such as its inability to get a good price for asset sell. Barriers to exit may be created, for example, wh invested in specialist equipment which is only suited to product, when the costs of retraining its workforce woul',
#  'usually taken as equalling 100',
#  'base rate noun the basic rate of interest on which charges on loans to its customers or interest on deposit are charged at a percentage above base rate and interest it.',
#  'base year noun the first year of an index, against wh in later years are measured',
#  'basis point noun one hundredth of a percentage po unit used in measuring market movements or interest rat',
#  'batch production noun production in small ba sensitive to the individual requirements of the customer It also allows better control over work teams.',
#  'Bayes, Thomas 18th century English clergym mathematician. He published his original theorem in 176',
#  'Bayesian statistics noun a statistical theory wh of what happened in the past alongside current obs estimate of the probability of something happening in th',
#  'Bayes’ theorem, Bayes’ Law noun the funda law which shows how confident someone can be in pr the future based on available evidence that something ha',
#  'bear noun STOCK EXCHANGE on the Stock Exchange shares, commodities or currency in the belief that the pr she will be able to buy again more cheaply later (NOTE: T',
#  'bearer bond, bearer security noun a bond wh bearer and does not have a name written on it. This i wishes to avoid being identified by the income tax autho',
#  'bear market noun a period when share prices fall are selling, since they believe the market will fall further',
#  'a bull market.)',
#  'beggar-my-neighbour policy noun action by its own commercial interests which has a bad effect on an action might be the introduction of swingeing tariffs local industry.',
#  'separated from a company’s normal accounts because the the company’s normal activities',
#  'benefit-cost analysis noun same as cost-benefit',
#  'Bentham, Jeremy (1748–1832) British economi the work of Adam Smith. He did not believe that public a were identical, but that the guiding principle of existence the individual, and that governments must apply themsel aim.',
#  'Bernoulli, Daniel (1700–82) Swiss mathemat hydrodynamics, gases, and harmonics as well as calculati in value of a person’s assets affects his or her moral expect',
#  'Bernoulli’s hypothesis noun the theory that involves not the consideration of possible money gain, bu losing the utility of the money being risked. It tak diminishing marginal utility of the money at risk.',
#  'Bertrand, Joseph (1822–1900) French mathem mainly on the theory of probability',
#  'Bertrand competition, Bertrand duopoly n pricing decisions by which Firm A believes that Firm B prices in response to a price reduction by Firm A; in fact, prices and Firm A reduces its prices again, ensuring tha drives the market, even if both firms may reach a point cover costs',
#  'bezzle noun money which had been illegally acquired wanted to profit from the US stock market in the 192 discovered when the stock market crashed. The term wa Galbraith. He saw that in boom periods, the bezzle increase depression it decreases because everyone is more careful in',
#  'bias noun error which occurs when carrying out random the results are either too high or too low',
#  'bid noun an offer to buy something (such as a share, cu company or a unit in a unit trust) at a certain price  ver particular price for something such as a share, commodity in a unit trust',
#  'bilateral aid noun aid from one country (the don country (the recipient). Compare multilateral aid',
#  'bilateralism noun government policy aimed at bal two countries where an imbalance exists. A government or other controls to reduce an unfavourable balance o country.',
#  'bilateral monopoly noun a situation in whic purchaser and only one supplier in a market, i.e. a m monopsony purchaser. This can occur when a gover weapons or when a single trade union is negotiating with',
#  'bilateral trade noun trade between two countries',
#  'bill noun 1. a written statement of what a person or com or services provided 2. US same as banknote (NOTE: T banknote.)  verb to send someone a bill for goods or',
#  'bill broker noun a firm which buys and sells Trea exchange for a fee',
#  'bill of exchange noun a document signed by the which tells another to pay money unconditionally to certain date. It is usually used in payments in foreign raising the bill is the drawer, the person who accepts seller can then sell the bill at a discount to raise cash. Thi A bill can also be accepted (i.e. guaranteed) by a bank.',
#  'birth rate noun the number of births per thousand of year. An increase in the birth rate will result in populatio a fall in the death rate. Currently the country with the Niger, with 51 births per 1,000, and the lowest is Latvia have to be seen in conjunction with infant mortality rates',
#  'BIS abbreviation Bank for International Settlements',
#  'black economy noun the part of an economy services which are paid for in cash, and therefore not d',
#  'called hidden economy, parallel economy, shad',
#  'Black Friday noun a sudden collapse on a stock m the first major collapse of the US stock market on Friday',
#  'against other currencies. It is not always seen as black, believe it was a good thing that the pound left the ERM.',
#  'Blue Book noun an annual publication of national sta UK government departments',
#  'blue-chip investments, blue-chip shares, b',
#  'noun shares of very large established companies which are investments',
#  'board of directors, board noun in the UK, a elected by the shareholders to run a company. In the USA elected by the shareholders to draw up company policy president and other executive officers who are responsibl company. The directors are elected by shareholders at the are usually chosen and nominated by the chairman or chief will consist of a chairman (who may be non-executive), a managing director, and a series of specialist directors in activities of the company (such as production director or company secretary will attend board meetings, but is no from the executive directors, who are in fact employees of may be several non-executive directors, appointed either and contacts, or as representatives of important sharehold These non-executive directors are paid fees. The board of be made up of a large number of non-executive directors a executive officers; a British board has more executive dire',
#  'bogof noun the practice of giving free gifts to customer for each one bought',
#  'bond noun a contract document promising to repay mo borrowed by a company or by the government at a certain fixed interest at regular intervals; such documents can be tr and their prices vary according to the length of time befo interest rate carried',
#  'COMMENT: Bonds are in effect another form of long-ter company or government. They can carry a fixed interest or but the yield varies according to the price at which they are b go up and down in the same way as share prices.',
#  'bonus issue noun a scrip issue or capitalisation issue transfers money from reserves to share capital and issues',
#  'abbreviation',
#  'Boston matrix noun a type of product portfoli products are identified as stars, question marks, cash co',
#  'Boston Consulting Group Share/Growth Matrix',
#  'bounded rationality noun the limits which certa dealing with complex issues like contracts. They tend t according to a rule of thumb, with the result that an org which involves several people making decisions individ procedure.',
#  'branch banking noun the situation in which a n through many local offices. This is the system that appli the USA banks tend to operate a unit banking system, w has only one unit under the umbrella of the local Federal',
#  'brand noun a make of product, which can be recogni distinctive design',
#  'brand loyalty noun the inclination of a customer t same brand and not to switch to another',
#  'breakeven analysis noun a calculation which s product will break even',
#  'breakeven point noun the point where total reven this is shown in break-even charts, e.g. charting the effe or an increase in fixed costs',
#  'break-up value noun the value of a company separately (rather than its value as an existing business)',
#  'Bretton Woods Agreement, Bretton Wood',
#  'international agreement reached in 1944, setting Monetary Fund and the World Bank, and a system of between currencies. At the Bretton Woods Conference th put forward a different plan to set up an institution simi clearing house. This was called the Keynes Plan.',
#  'British Technology Group noun a British gov formed in 1981 from the National Enterprise Board (N Research and Development Corporation (NRDC). It manage intellectual property rights and invests in new',
#  'deal carried out',
#  'BTG abbreviation British Technology Group',
#  'bubble noun a continued rise in the value of an asset, su which is caused by people thinking that the price will con nothing to do with the inherent value of the asset, and will c speculators decide that the rise cannot continue. The most the South Sea Bubble in the 1720s, where speculators dr shares in companies trading in the Pacific area. A recent bu the value of shares in electronic and internet companies in',
#  'called speculative bubble',
#  'budget noun a plan of expected spending and incom year). In general, the term refers to the annual plan of tax spending proposed by a finance minister, but is also used t planning for companies and individuals.  verb to set asi for expected spending and income',
#  'budgetary control noun the use of budgets to contr of a company. Actual spending or income is compared re figures, and managers use the results to plan future actions',
#  'budget constraint noun a requirement to make purchase of different goods at different prices, given that fixed amount of money to spend',
#  'budget deficit noun 1. the deficit in a country’s pla income from taxation will not be sufficient to pay for expenditure. It has to be financed by borrowing.  st deficit 2. a deficit in personal finances where a househ finance large purchases which cannot be made out of incom',
#  'budget line noun a graph showing the different qua goods which could be purchased at different prices, given has a fixed amount of money to spend. It is used in c indifference curve to identify to identify the goods and thei customer might want to purchase. Also called consum',
#  'curve',
#  'budget surplus noun a situation in which reven expenditure, the excess being put into savings',
#  'operate in much the same way as banks. Indeed, many b changed from mutual status, where the owners of the so and borrowers, to become publicly-owned banks. institutions are the savings & loan associations, or thrif are regulated by the Building Societies Ombudsma investigate complaints by members of the public again All building societies belong to the Building Societies O',
#  'built-in stabilisers plural noun same as automa',
#  'bull noun on the Stock Exchange, a person who believ and therefore buys shares (or commodities or currency) t later (NOTE: The opposite is a bear.)',
#  'bullion noun gold or silver bars',
#  'bull market noun a period when share prices ris optimistic and buy shares (NOTE: The opposite is a bear',
#  'business cycle noun a period during which trade down, then expands again. Also called trade cycle',
#  'business rate noun a tax levied on business proper',
#  'is local property tax.)',
#  'buyer concentration noun the number of bu market can be dominated by a few buyers or by a single',
#  'buyer’s market noun a market where shares, com are sold cheaply because there is more stock available The opposite is a ‘seller’s market’. (NOTE: The opposite is',
#  'by-product noun a secondary product made as a res main product which can be sold for profit',
#  'cabotage noun restriction of the transport of goods foreign hauliers. It is seen as contrary to the principles of f',
#  'call noun the price established during a trading session',
#  'called up capital noun share capital in a compan called up. The share capital becomes fully paid when all th have been called up.',
#  'call money noun money loaned for which repaymen without notice. It is used by commercial banks, placin short-term deposit with discount houses. Also called',
#  'money on call',
#  'call option noun an option to buy shares at a future d price (NOTE: The opposite is a put option.)',
#  'Cambridge equation noun an equation which sho money multiplied by its velocity of circulation equals the times the number of goods sold. This shows that a stable between the stock of money and the national income.',
#  'Cambridge school of economics noun a developed at Cambridge University called classical ec Keynes’ theories and emphasising macroeconomics, neoclassical economics which emphasised a microeconom',
#  'canon of taxation noun one of a series of criteria d Smith to judge if a tax is good. The four canons are (a) th the tax should be much lower than the amount collected; be told how much to pay and when to pay it; (c) the payment must be convenient for the payer; (d) the tax sh ability of the taxpayer to pay it.',
#  'CAP abbreviation Common Agricultural Policy',
#  'capacity noun the amount which can be produced, or a can be done, or the amount of use made of the factors capacity means that full use is made of the factors.',
#  'capacity utilisation noun output shown as a percen',
#  'capital noun property, assets and finished goods used one of the four factors of production.',
#  'assets, such as machinery, which may be deducted from and so reduce its tax liability. Under current UK law allowable for tax on profits, whereas capital allowances, fixed assets owned by the company, are tax-allowable.',
#  'capital appreciation noun same as appreciatio',
#  'capital asset pricing model noun a model which can be used to estimate different returns from investments as well as the value of a company’s shares.',
#  'capital assets plural noun property or machine owns and uses, but which the company does not buy regular trade. Capital assets are divided into tangible fi fixed assets and investments. Also called fixed assets',
#  'capital budgeting noun budgeting for planned assets during the next budget period',
#  'capital consumption noun the decrease in the v firm’s stock of capital goods held as they wear out and n',
#  'Capital Consumption Allowance noun the c the economy during a year, deducted from GDP to g product (NDP). Abbreviation CCA',
#  'capital deepening noun increased investment of without changing other factors of production. Also calle',
#  'capital employed noun shareholders’ funds plus business.  return on capital employed',
#  'capital equipment noun equipment which a fac work or in production',
#  'capital expenditure noun money spent on ca property, machines and furniture. Also called capital in',
#  'outlay',
#  'capital flight noun the rapid movement of capi because of lack of confidence in that country’s economic political unrest, war, or other conditions. Also called flig',
#  'capital flow noun the movement of investment cap to another. Also called capital movement, moveme',
#  'capital inflow noun movement of capital into a count in companies, buying whole companies or other forms of i',
#  'capital intensity noun the level of being capital-inte ratio of capital to labour in a production process',
#  'capital-intensive adjective (economy or business) amount of capital in proportion to labour',
#  'capital investment noun same as capital expend',
#  'capitalisation noun the value of a company calcula the price of its shares on the Stock Exchange by the numb',
#  'Also called market capitalisation',
#  'capitalisation issue noun a bonus issue, free is where a company transfers money from reserves to share free extra shares to the shareholders. The value of the co same, and the total market value of shareholders’ shares The market price is adjusted to account for the new shares.',
#  'capitalised value noun the value of a business calc two methods: the present value of future income or the sh by the number of the shares in issue',
#  'capitalism noun the economic system where each per invest money, to work in competitive business and to bu restriction from the state',
#  'capital-labour ratio noun the ratio of capital to lab process',
#  'capital loss noun a loss made when selling assets (N',
#  'capital gain.)',
#  'capital market noun a financial market dealing i financial instruments used by companies to get funds. It companies can look for long-term investment capital.',
#  'capital movement noun same as capital flow',
#  'capital outflow noun the movement of capital out o form of investments in other countries',
#  'capital outlay noun same as capital expenditure',
#  'trading. These reserves cannot be distributed to the shar company is wound up. Also called undistributable re',
#  'capital stock noun the total value of physical stock country or firm',
#  'capital to asset ratio, capital/asset ratio no adequacy',
#  'capital transfer tax noun formerly, a tax on gifts or property',
#  'capital widening noun same as capital deepen',
#  'CAPM abbreviation capital asset pricing model',
#  'cardinal utility noun the measurement of the consumer gets from a good or service, based on the satisfaction can be accurately measured; as opposed to ‘ the satisfaction can only be seen to be growing in com measurement',
#  'carry-over noun the fact of not paying an account o later. Also called contango',
#  'cartel noun a group of companies which try to fix th the supply of a product, because they can then profit fro',
#  'cash noun money in coins or notes. Cash in circulatio supply.  verb to convert something such as a cheque i notes',
#  'cash cow noun a product which consistently gener maintains its dominant position in the market, but wil because the market is only expanding slowly',
#  'cash crop noun an agricultural crop grown for sale other countries, rather than for domestic consumption',
#  'cash discount noun a discount given for paymen',
#  'discount for cash',
#  'cash flow noun a record of the cash which comes sales (cash inflow) less the money which goes out in p expenditure (cash outflow) during a certain period',
#  'percentage laid down by the central bank). Banks are requi their liabilities in the form of cash ratio deposits.',
#  'casual unemployment noun short-term periods between jobs',
#  'caveat emptor noun ‘let the buyer beware’, the prin is responsible that goods being bought are satisfactory',
#  'CBI abbreviation Confederation of British Industry CCA abbreviation current cost accounting',
#  'CD abbreviation certificate of deposit',
#  'ceiling noun a highest point, such as the highest interes amount of money which a depositor may deposit',
#  'central bank noun the main government-controlled which controls the financial affairs of the country by fixing issuing currency, supervising and acting as banker to the and controlling the foreign exchange rate',
#  'central government noun the main governmen opposed to local or provincial governments',
#  'central planning noun a system where the gov business activity, regulates supply, sets production targets to be done. Also called state planning. Compare comm',
#  'Central Statistical Office noun the British g charged with collecting and publishing national statistics. with the Office of Population Censuses and Surveys to f National Statistics (ONS). Abbreviation CSO',
#  'certificate of deposit noun a document from a money has been deposited at a certain guaranteed interes period of time. A CD is a bearer instrument, which can be It can be sold at a discount to the value, so that the yield o are traded on the secondary market by discount houses a traded on LIFFE. Abbreviation CD',
#  'certificate of incorporation noun a document is House to show that a company has been incorporated',
#  'change in demand noun the change in the level or services caused by factors other than price. It is sh demand curve.',
#  'change in supply noun the change in the level o services caused by factors other than price. It is shown a curve .',
#  'channel of distribution noun same as distribu',
#  'chaos theory noun the theory describing how, whe to small differences in initial values, the future behavio become unpredictable',
#  'CHAPS abbreviation Clearing House Automated Pay',
#  'Chapter 11 noun the section of the US Bankrupt which allows a corporation to be protected from d creditors for a period of time, while it is reorganised wit debts. The officers of the corporation will negotiate with best way of reorganising the business.',
#  'Chapter 13 noun the section of the US Bankrupt which allows a business to continue trading and to pa regular monthly payments over a period of time',
#  'Chapter 7 noun the section of the US Bankruptcy Re sets out the rules for the liquidation of an incorporated c',
#  'charge account noun an arrangement which a cus to buy goods and to pay for them at a later date, usuall sent at the end of the month. The customer will m payments into the account and is allowed credit of payments.',
#  'chartist noun a person who studies stock market trend rises or falls',
#  'cheap money noun money which can be borro interest',
#  'check noun US same as cheque',
#  'checking account noun US same as current ac',
#  'there is no money in the account',
#  'Chicago School noun a school of economists, base of Chicago, led by Professor Milton Friedman, who belie rules economic behaviour, that money supply determines is pointless for governments to hope to control the econom',
#  'child benefit noun money paid by the government children, currently for each child under 16',
#  'Chinese walls plural noun imaginary barriers betw the same organisation, set up to avoid insider dealing or a (as when a merchant bank is advising on a planned investment department should not know that the bid is ta would advise their clients to invest in the company being t',
#  'CHIPS abbreviation Clearing House Interbank Payment CIF, c.i.f. abbreviation cost, insurance and freight',
#  'circular flow of income noun the flow of in producers and the households who buy their goods or serv from households to producers as the households purchase income moves from producers to households in the form o',
#  'circulating capital noun capital in the form of ca materials, finished products and work in progress require carry on its business. Also called working capital',
#  'city noun the old centre of London, where banks and lar their main offices; the British financial centre',
#  'City Code on Takeovers and Mergers noun which regulates how takeovers should take place. It i Takeover Panel.',
#  'City Panel on Takeovers and Mergers',
#  'Takeover Panel',
#  'classical economics noun economic theories abou in an economy which see the market as essentially a me wealth between capitalists, landowners and labour. These any possibility of recession or unemployment because it by market forces. The theories are typified in the writin David Ricardo and John Stuart Mill.',
#  'cheques, or where stock exchange or commodity exch settled',
#  'Clearing House Automated Payments',
# ...
#  'exogenous money noun money which is put system from outside, where production and prices react t The opposite, money which is inside the banking system money or inside money. Also called outside money',
#  'exogenous variable noun a variable outside which affects the model but is not affected by it. Com',
#  'variable',
#  'expectations plural noun what people think will have a major influence on economic decisions in p uncertainty when there is no clear picture of future trend',
#  'expectations-augmented Phillip',
#  'expectations-adjusted Phillips curve version cur',
#  'rate of inflation is taken into account when measuring demand',
#  'expectations lag noun the period which elapses value of a variable changes to allow for a change in adaptive expectations it is the time which elapses betwe observation of a trend by an individual and the c expectations caused by it.',
#  'expected inflation, expected rate of inflati',
#  'inflation which the public expects to exist in the future measure it accurately.',
#  'expenditure switching noun the moving of presen one purchase to another, such as from purchasing imp home-produced goods',
#  'expenditure tax noun a tax on money as it is sp income tax which taxes income as it is received. An sometimes considered a better progressive tax in that in income spend less than those with high incomes. VAT, sa and customs duty are all expenditure taxes.',
#  'explicit cost noun the cost of paying for factors inv producing a good or service where the factors come from The opposite, implicit cost represents payments for fac actually produces or owns itself.',
#  'exploitation noun the use of someone’s labour cheap underpaying its workers or by a developed country payi from a developing country',
#  'exponent noun number indicating how many times a b multiplied to produce a certain power. It is printed in small base number.',
#  'exponential adjective with a variable exponent which e, the basis of a natural logarithm',
#  'export noun 1. a product which is sold and transported t',
#  'exports 2. the practice or business of sending goods to be sold  verb to sell and transport a product to a foreign c',
#  'Export Credits Guarantee Department noun department which insures sellers of exports sold on possibility of non-payment by the purchasers. Abbreviation',
#  'export incentive noun a way of encouraging export credit, subsidies for exported goods or special tax c exporters pay lower tax on profits from exports',
#  'export-led growth noun growth in a national econo by increased exports. It is less inflationary than domestic g',
#  'ex post adverb as seen after the event. Compare ex a',
#  'exposure to risk noun the amount of risk which has. Exposure can be the amount of money lent to a exposure to a foreign country) or the amount of money w lose if his investments collapse (such as his or her expo market).',
#  'extended fund facility noun a means of giving whose economies are suffering from balance of paymen to standby credit but with longer repayment terms',
#  'external balance noun the situation in which a c the same amount as other countries invest in it. It i currency reserves and a low overseas debt.',
#  'external benefits plural noun  externalities external costs plural noun  externalities external debt noun money owed by foreign countri external deficit noun a deficit in a country’s balan external diseconomy noun  externalities external economy noun  externalities',
#  'external growth noun the growth of a firm by buy rather than by expanding existing sales or products (',
#  'internal growth or organic growth.)',
#  'externalities plural noun costs or benefits invol which do not accrue to the individual or firm which transaction. External costs (or external diseconomies) m to the environment from a mining industry, while external economies) could be the pleasure incurred in an by hydroelectric works.',
#  'external labour market noun a system in organisation are advertised so that people working ou can apply. This is opposed to an internal labour marke given to employees already working in the organisation.',
#  'based on an extrapolation of existing trends, i.e. assuming will continue at the same rate',
#  'or bill of exchange. Also called nominal value, par v',
#  'factor cost noun the value of a good or service as th not including tax such as VAT',
#  'factor endowment noun the factors of productio available',
#  'factor income noun income which comes fro production, such as hiring out labour or renting land',
#  'factoring noun the business of buying debts from a then getting the debtors to pay. Many businesses resort to their cash flow.',
#  'factor market noun the market for a factor of pr labour market or the capital market',
#  'factor of production noun one of the four thing product (land, labour, machinery and capital)',
#  'factory gate price noun the price of a product bo manufacturer. The factory gate price includes direct cos materials and energy, and overhead costs such as int maintenance and rent.',
#  'fair trade noun an international business system in w import duties on certain items imported from their tr those imports are believed to be unfairly cheap, usual costs which are cheaper than in the importing country',
#  'Fair Trading Act 1973 noun an act which provi of monopolies and competition and set up the Office of F',
#  'Family Expenditure Survey noun since 19 official survey of household income and expenditure b about 10,000 households. It covers incomes and expe regularly paid items, such as gas, electricity and tele insurance, travel costs and hire purchase costs. The resu the weighting for the RPI. Abbreviation FES',
#  'Fannie Mae noun same as Federal Na Association (informal)',
#  'fao abbreviation for the attention of',
#  'FDIC abbreviation Federal Deposit Insurance Corporatio',
#  'Fed noun US same as Federal Reserve Board (infor',
#  'Federal Deposit Insurance Corporation n agency which supervises banks, guarantees investors’ depo that financial products and services give a fair deal Abbreviation FDIC',
#  'Federal funds plural noun deposits by commercial Federal Reserve Banks, which can be used for short-term l Also called Fed funds',
#  'Federal Home Loan Bank Board noun a f agency set up in 1932 to supervise the Federal Home Lo regulated all savings and loan associations and was repla Federal Housing Finance Board. Abbreviation FHLBB',
#  'Federal Home Loan Bank System noun a which provided credit to institutions making home lo Originally it was supervised by the Federal Home Loan Ba by the Federal Housing Finance Board. Abbreviation FHL',
#  'Federal Housing Finance Board noun a US Fe in 1989 to regulate the Federal Home Loan Banks. Abbrev',
#  'Federal National Mortgage Association',
#  'owned US organisation that regulates mortgages and hel backed by Federal funds. Abbreviation FNMA. Also calle',
#  'Federal Reserve noun a system of federal govern US banks, in which the Federal Reserve Board regulates m money, fixes the discount rate and issues government bond central bank of the USA. It is run by the Federal Reser chairman and seven committee members (or governors) w by the President. The twelve Federal Reserve Banks an branches act as lenders of last resort to local commercial b board is appointed by the President, the whole sy independent of the US government.',
#  'Federal Reserve Bank noun one of the twelve re USA which with their twenty-five branches are owned directed by the Federal Reserve Board. Abbreviation FRB',
#  'FHLBB abbreviation Federal Home Loan Bank Board FHLBS abbreviation Federal Home Loan Bank Syste',
#  'fiat money noun coins or notes which are not wo metal, but are said by the government to have a value legal tender',
#  'fiduciary issue noun bank notes which are not which have a value printed on them and are accepted as',
#  'FIFO abbreviation first in first out',
#  'FIMBRA abbreviation Financial Intermediaries, M Regulatory Association',
#  'final product noun a manufactured product or fini bought by the final user, such as an individual consumer',
#  'finance noun 1. money available for investment, as use 2. the business of managing money  verb to p investment, as a loan or for a similar use',
#  'Finance Act noun the annual act of the UK Parlia government the power to obtain money from taxes as pr',
#  'finance company, finance corporation noun part of a commercial bank, which buys goods or equipm or leases to companies or individuals. Also called finan',
#  'Finance Corporation for Industry noun an 1945 to channel money from city institutions to help merged with the ICFC in 1973 to form Finance for In renamed 3i (Investors in Industry) in 1983 and subseq Stock Exchange. Abbreviation FCI',
#  'finance house noun same as finance company',
#  'financial accounting noun the recording of fin monetary terms according to accounting standards and le',
#  'Financial Accounting Standards Board',
#  'regulates accounting standards in the USA. Abbreviation',
#  'financial assets plural noun assets in the form certificates which can be liquidated (such as gover certificates or fixed-interest bonds)',
#  'financial instrument noun any form of investment or in other financial markets, such as shares, government st deposit, bills of exchange, etc.',
#  'Financial Intermediaries, Managers Regulatory Association noun one of the self replaced by the FSA, originally set up to regulate the activ as financial advisers and insurance brokers, giving f arranging financial services for small clients. Abbreviation',
#  'financial intermediary noun an institution whic loans from individuals and lends money to clients. Banks and hire purchase companies are all types of financial inter',
#  'financial ratios plural noun ratios which relate to t of a firm (such as current ratio, dividend cover or P/E ratio',
#  'financial sector noun the part of the private sect which deals with money, including banks, building soc funds',
#  'financial security noun a financial instrument debentures or treasury bonds which are issued by c government and can be traded',
#  'Financial Services Act noun an act of the UK regulates the offering of financial services to the general p investors',
#  'Financial Services Authority noun a UK gove up to regulate all financial services, such as banks, stock pension companies, professional bodies and stock excha ombudsmen for these services. Abbreviation FSA',
#  'Financial Times noun an important British financi (printed on pink paper). Abbreviation FT',
#  'Financial Times Index, Financial Times Ordi',
#  'an index of 30 major industrial and commercial comp London Stock Exchange. It does not include banks, insur other financial institutions.',
#  'financial year noun the twelve-month period for produces accounts (not necessarily the same as a calendar',
#  'stocks in hand were purchased last, and that stocks sold d purchased first. Compare last in first out',
#  'first-order conditions plural noun conditions variable to be stationary at zero. Compare second-ord',
#  'fiscal drag noun the effect of inflation on a govern As inflation increases so do prices and wages, an proportionately. Even if inflation is low, increased e government increased revenues anyway.',
#  'fiscal federalism noun the sharing of revenues central government and regional or local authorities. T raised by either authority and switched between them, governments and passed to the EU for distribution.',
#  'fiscal illusion noun the introduction or existence o taxes) which are not transparent, and which the public w know exist',
#  'fiscal neutrality noun a tax system which does no It is very difficult for a tax system to be devised w incentives to adopt one policy as opposed to another.',
#  'fiscal policy noun the government’s policy rega revenues to influence the economy. An expansionary po increasing government spending could encourage emplo policy of increasing tax and cutting government spe demand in the economy.',
#  'fiscal year noun a twelve-month period on which ta the UK, 6 April to 5 April)',
#  'Fisher equation noun an equation devised by the Fisher, which shows the quantity theory of money. Th (where M = amount of money, V = velocity of circulati level and T the transactions which take place) is always',
#  'fixed assets plural noun property which a compan which the company does not buy or sell as part of its re the company’s investments in shares of other companies',
#  'fixed capital noun capital in the form of fixed ass machinery)',
#  '(as from an annuity)',
#  'fixed-interest securities plural noun securities (s bonds) which produce an interest which does not change',
#  'fixed investment noun an investment in fixed asset or machinery',
#  'fixed rate noun an interest rate which is fixed and during the life of the agreement',
#  'flag of convenience noun a flag flown by a ship w national of the country concerned; usually granted by cou fully respect international shipping laws and often a cov illegal practice',
#  'flat yield noun the interest rate shown as a percentage o fixed-interest stock',
#  'flight to quality noun the tendency of investors to securities when the economic outlook is uncertain',
#  'float noun an amount of cash taken from a central su running expenses  verb to start a new company by sellin Stock Exchange',
#  'floating capital noun same as working capital',
#  'floating charge noun a charge linked to any or al assets of a certain type, but not to any specific item',
#  'floating debenture noun a debenture secured on assets which runs until the company is wound up, w becomes fixed',
#  'floating debt noun any short-term part of the nati Treasury bills',
#  'floating exchange rate noun an exchange rate fo can vary according to market demand, and is not fixed by t',
#  'floating rate noun same as variable rate',
#  'flotation noun the action of starting a new company by on the Stock Exchange',
#  'organize food distribution in areas of famine. Abbreviati',
#  'footloose industry noun an industry which is not area and which can be relocated anywhere to take advan (a call centre as opposed to a coal mine)',
#  'Footsie noun same as FTSE 100 (informal)',
#  'forced saving noun a situation in which a govern and does not increase public expenditure. This forces',
#  'less. Also called involuntary saving',
#  'forecast dividend noun a dividend which a comp the end of the current year. Also called prospective d',
#  'forecasting noun calculation of what will probably',
#  'foreclosure, foreclosing noun the act of forcing because the owner cannot repay money which he or sh the property as security',
#  'foreign aid noun help given to a less developed country',
#  'foreign balance noun that part of a country’s which is represented by foreign trade',
#  'foreign currency noun the currency (i.e. money) foreign currency account is a bank account in the curren (e.g. a dollar account in the UK).',
#  'foreign currency reserves plural noun money held by a country and used to settle international debts. part of a country’s foreign currency reserves. A',
#  'exchange reserves, international reserves',
#  'foreign direct investment noun investment in by foreign companies or governments. Abbreviation FD',
#  'foreign exchange noun 1. foreign currencie exchanging of the money of one country for that of anot',
#  'foreign exchange controls plural noun gover changing the local currency into foreign currency',
#  'outside the country',
#  'foreign trade noun trade with other countries. Als',
#  'trade, overseas trade',
#  'foreign trade multiplier noun the effect of a domestic economy which not only increases trade in dom goods but also increases imports',
#  'forex, Forex noun same as foreign exchange',
#  'forfaiting noun the providing of finance for exporters. forfaiter) accepts a bill of exchange from an overseas custo the bill at a discount, and collects the payments from th course.',
#  'forwardation noun the difference between the spot an when the spot price of a commodity or currency is lower th',
#  '(NOTE: The opposite is backwardation.)',
#  ...]

# %%
len(terms_use)
# Out:
# 2366

# %%
term_all, defn_all = [], []
n = 0
for  ind in range(len(terms_use)):
  term = terms_use[ind]
  for i in soup.find_all('p')[n:]:
    if term in i.text:
      term_all.append(term)
      defn_all.append(i.text.replace(term, '').replace('noun', '').replace('plural','').replace('adverb', '').replace('verb','').replace('abbreviation', '').strip())
      n = n + 1
      break

# %%
len(defn_all)
# Out:
# 2366

# %%
heather_df = pd.DataFrame({'terms':term_all, 'definitions':defn_all})

# %%
heather_df.sample(60)
# Out:
#                           terms                                        definitions
# 11              monetary policy                                    accommodating ,
# 140                        bear  banknote  a promissory note issued by a bank e...
# 1955               share option  the right to buy or sell shares at time in the...
# 1365            nationalisation   , nationalization  the tak industry by the state
# 356                   convexity  the convex shape of a curve. The the a set are...
# 1128                        L/C           LBO  leveraged buyout   letter of credit
# 1100        kinked demand curve  a demand curve w believe that if they raise th...
# 218           capital equipment        equipment which a fac work or in production
# 521                payout ratio  dividend cover, dividend   profits which is pa...
# 1084              issuing house                                         term is .)
# 1221           management buyin  the purchase of a comp outside directors. Abbr...
# 2297                wages drift  wage drift  the difference between wages and m...
# 1847              risk analysis  an analysis of how much ca through various mar...
# 942               impact effect  the immediate effect of an eco an increase in ...
# 995           industrial sector  the sector of the economy de which produces go...
# 985   indirect utility function  a function sho goods consumed as a utility of ...
# 675     exchange rate mechanism         ERDF  European Regional Development Fu ERM
# 1266                 estimation  maximum-likelihood   th parameter values which...
# 1166             liquidity trap  a situation in which a govern reducing real in...
# 2089            structural form  the reduced form of an econ has been restructu...
# 626                    analysis  double counting  the counting of a cost or whe...
# 743          financial security  a financial instrument debentures or treasury ...
# 1474                     option  on the Stock Exchange, the action of givin to ...
# 2052           stationary state  a theoretical state of an consumes exactly wha...
# 253                central bank  percentage laid down by the ). Banks are requi...
# 2317              wasting asset  an asset which becomes grad time goes by (such...
# 534               double option  the option to buy or sell at future (a combina...
# 2188              trade balance  the international trading positi merchandise, ...
# 1339            multilateralism  a policy of expanding intern many countries, r...
# 1784                  reflation  the act of stimulating the economy by supply o...
# 84                          AVC                              average variable cost
# 1703               pump priming  government investment in new hopes will benefi...
# 877                 green pound  the value of the pound sterling agricultural p...
# 2026   speculative unemployment  a form which workers reduce the hours they wor...
# 875                 Green Paper  a report from the UK governm new law to be dis...
# 1991                      slump  recognition lag  the time it takes for policym...
# 1544                    payroll  the list of people employed and paid by  tax  ...
# 631                   equal pay  the situation in which all workers same jobs, ...
# 1380                        NEB                          National Enterprise Board
# 2329                Green Paper  White Paper  a proposal from the UK governme b...
# 906              Heckscher, Eli  (1879–1952) Swedish econom mercantilism as the...
# 1633                price taker  a small trader on a market, whose a effect on ...
# 1580                       PPBS  budgeting which is based on details of objecti...
# 229              capital-labour         ratio  the ratio of capital to lab process
# 2355      yardstick competition  a method used by a performance of a group of m...
# 988        industrial democracy  a situation in which t say in the running of a...
# 2323           weighted average  an average which is cal factors into account, ...
# 771          footloose industry  an industry which is not area and which can be...
# 750                 fiscal drag  the effect of inflation on a govern As inflati...
# 1903                 Schedule F  the schedule to the Finance Ac charged on inco...
# 1079              isocost curve  a graph showing the amounts factors that can b...
# 1213               macroeconomy                         the economy of a whole are
# 1957      share premium account  a part of a compan when the difference in shar...
# 406                  cum coupon  the price of a bond including th next interest...
# 161                         BIS  Bank for International Settlements  a clearing...
# 1526             redistribution  Pareto-optimal   the redis from one person to ...
# 1452                  oligopoly             a situation in which only a few seller
# 1572                        PIA  Personal Investment Authority  a self-r regula...
# 1408                new economy  the part of a country’s economy new technologi...
# 2268                    utility  total   the whole satisfaction of each indivi ...

# %%
heather_df.to_csv('heather_df.csv', index = False)

# %% [markdown]
# # Heather : will do later

# %% [markdown]
# # Mankiw

# %%
soup = BeautifulSoup(open("mankiw.html", "r"), 'html.parser')

# %%
terms = [i.text for i in soup.find_all('span', {'class' : 'ft3'})]

# %%
terms

# %%
all_texts = [i.text for i in soup.find_all('p') if 'Cengage Learning' not in i.text and 'Editorial review' not in i.text]

# %%
use_terms = []
use_definitions = []
n = 0
for term in terms:
  for txt in all_texts[n:]:
    if term in txt:
      use_terms.append(term)
      use_definitions.append(txt.split('\u2002')[1])
      n = n + 1

# %%
mankiw = pd.DataFrame({'terms':use_terms, 'definitions':use_definitions})
mankiw['source'] = 'mankiw_copyright'
mankiw
# Out:
#                   terms  ...            source
# 0    absolute advantage  ...  mankiw_copyright
# 1     accounting profit  ...  mankiw_copyright
# 2     adverse selection  ...  mankiw_copyright
# 3                 agent  ...  mankiw_copyright
# 4                 agent  ...  mankiw_copyright
# ..                  ...  ...               ...
# 294             welfare  ...  mankiw_copyright
# 295             welfare  ...  mankiw_copyright
# 296   welfare economics  ...  mankiw_copyright
# 297  willingness to pay  ...  mankiw_copyright
# 298         world price  ...  mankiw_copyright
#
# [299 rows x 3 columns]

# %%
scores = mankiw['definitions'].apply(lambda x: extract_scores(str(x)))
scores_df = pd.DataFrame(list(scores))
scores_df.columns = ['flesch_reading_ease','flesch_kincaid_grade','smog_index','coleman_liau_index','automated_readability_index','dale_chall_readability_score','difficult_words','linsear_write_formula','gunning_fog','text_standard','fernandez_huerta','szigriszt_pazos','gutierrez_polini','crawford','gulpease_index','osman']

mankiw_scores_df = pd.concat([mankiw.reset_index(),scores_df.reset_index()], axis = 1).drop('index', axis = 1)
mankiw_scores_df
# Out:
#                   terms  ...  osman
# 0    absolute advantage  ...  63.68
# 1     accounting profit  ...  57.68
# 2     adverse selection  ...  45.50
# 3                 agent  ...  66.69
# 4                 agent  ...  70.41
# ..                  ...  ...    ...
# 294             welfare  ...  46.57
# 295             welfare  ...  46.74
# 296   welfare economics  ...  46.74
# 297  willingness to pay  ...  99.50
# 298         world price  ...  93.31
#
# [299 rows x 19 columns]

# %%
mankiw_scores_df.drop_duplicates('terms').to_csv('mankiw.csv', index = False)
